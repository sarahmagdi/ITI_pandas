# %%
import pandas as pd

# %%
html_tables = pd.read_html('https://hoopshype.com/salaries/players/')
type(html_tables)
# Out:
# list

# %%
len(html_tables)
# Out:
# 1

# %%
type(html_tables[0])
# Out:
# pandas.core.frame.DataFrame

# %%
NBA_players_df = html_tables[0]
NBA_players_df.head()
# Out:
#    Unnamed: 0             Player      2021/22      2022/23      2023/24  \
# 0         1.0      Stephen Curry  $45,780,966  $48,070,014  $51,915,615
# 1         2.0       James Harden  $44,310,840  $47,366,760           $0
# 2         2.0          John Wall  $44,310,840  $47,366,760           $0
# 3         4.0  Russell Westbrook  $44,211,146  $47,063,478           $0
# 4         5.0       LeBron James  $41,180,544  $44,474,988           $0
#
#        2024/25      2025/26 2026/27
# 0  $55,761,217  $59,606,817      $0
# 1           $0           $0      $0
# 2           $0           $0      $0
# 3           $0           $0      $0
# 4           $0           $0      $0

# %% [markdown]
# ### Let's do another trial

# %%
tables_in_wikipedia_page = pd.read_html('https://en.wikipedia.org/wiki/Egypt_national_football_team')
len(tables_in_wikipedia_page)
# Out:
# 80

# %% [markdown]
# #### There're 80 tables!!!, so let's try to be more specific

# %%
more_specific_tables_in_wikipedia_page = pd.read_html('https://en.wikipedia.org/wiki/Egypt_national_football_team', match='Top goalscorers')
len(more_specific_tables_in_wikipedia_page)
# Out:
# 2

# %%
more_specific_tables_in_wikipedia_page[0]
# Out:
#                                                     0  \
# 0   Most appearances Rank Player Caps Goals Career...
# 1                                                Rank
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  8
# 11                                                 10
# 12                                               Rank
# 13                                                  1
# 14                                                  2
# 15                                                  3
# 16                                                  4
# 17                                                  5
# 18                                                  6
# 19                                                  7
# 20                                                  8
# 21                                                  9
# 22                                                  9
#
#                                                     1  \
# 0   Top goalscorers Rank Player Goals Caps Ratio C...
# 1                                              Player
# 2                                        Ahmed Hassan
# 3                                    Hossam Hassan[a]
# 4                                     Essam El Hadary
# 5                                         Ahmed Fathy
# 6                                      Ibrahim Hassan
# 7                                          Hany Ramzy
# 8                                          Wael Gomaa
# 9                                       Ahmed El Kass
# 10                               Abdel Zaher El Sakka
# 11                                       Rabie Yassin
# 12                                             Player
# 13                            Hossam Hassan[a] (list)
# 14                                      Mohamed Salah
# 15                                   Hassan El Shazly
# 16                                 Mohamed Abou Trika
# 17                                       Ahmed Hassan
# 18                                           Amr Zaki
# 19                                        Emad Moteab
# 20                                      Ahmed El Kass
# 21                                  Mahmoud El Khatib
# 22                                  Gamal Abdel Hamid
#
#                                                     2      3             4  \
# 0   Ahmed Hassan has the most caps of any African ...    NaN           NaN
# 1                                                Caps  Goals        Career
# 2                                                 184     33     1995–2012
# 3                                                 176     68     1985–2006
# 4                                                 159      0     1996–2018
# 5                                                 136      3  2002–present
# 6                                                 131     14     1988–2002
# 7                                                 123      3     1988–2003
# 8                                                 114      1     2001–2013
# 9                                                 112     25     1987–1997
# 10                                                112      4     1997–2010
# 11                                                109      1     1982–1991
# 12                                              Goals   Caps         Ratio
# 13                                                 68    176          0.39
# 14                                                 45     74          0.61
# 15                                                 42     62          0.68
# 16                                                 38    100          0.38
# 17                                                 33    184          0.18
# 18                                                 30     63          0.48
# 19                                                 28     70           0.4
# 20                                                 25    112          0.22
# 21                                                 24     54          0.44
# 22                                                 24     79           0.3
#
#                5
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12        Career
# 13     1985–2006
# 14  2011–present
# 15     1961–1975
# 16     2001–2013
# 17     1995–2012
# 18     2004–2013
# 19     2004–2015
# 20     1987–1997
# 21     1974–1986
# 22     1979–1993

# %%
more_specific_tables_in_wikipedia_page[1]
# Out:
#    Rank                   Player  Goals  Caps  Ratio        Career
# 0     1  Hossam Hassan[a] (list)     68   176   0.39     1985–2006
# 1     2            Mohamed Salah     45    74   0.61  2011–present
# 2     3         Hassan El Shazly     42    62   0.68     1961–1975
# 3     4       Mohamed Abou Trika     38   100   0.38     2001–2013
# 4     5             Ahmed Hassan     33   184   0.18     1995–2012
# 5     6                 Amr Zaki     30    63   0.48     2004–2013
# 6     7              Emad Moteab     28    70   0.40     2004–2015
# 7     8            Ahmed El Kass     25   112   0.22     1987–1997
# 8     9        Mahmoud El Khatib     24    54   0.44     1974–1986
# 9     9        Gamal Abdel Hamid     24    79   0.30     1979–1993

# %%
historical_goalers_of_Egypt_df = more_specific_tables_in_wikipedia_page[1]
historical_goalers_of_Egypt_df
# Out:
#    Rank                   Player  Goals  Caps  Ratio        Career
# 0     1  Hossam Hassan[a] (list)     68   176   0.39     1985–2006
# 1     2            Mohamed Salah     45    74   0.61  2011–present
# 2     3         Hassan El Shazly     42    62   0.68     1961–1975
# 3     4       Mohamed Abou Trika     38   100   0.38     2001–2013
# 4     5             Ahmed Hassan     33   184   0.18     1995–2012
# 5     6                 Amr Zaki     30    63   0.48     2004–2013
# 6     7              Emad Moteab     28    70   0.40     2004–2015
# 7     8            Ahmed El Kass     25   112   0.22     1987–1997
# 8     9        Mahmoud El Khatib     24    54   0.44     1974–1986
# 9     9        Gamal Abdel Hamid     24    79   0.30     1979–1993
